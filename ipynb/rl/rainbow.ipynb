# %% [markdown]
# <a href="https://colab.research.google.com/github/komo135/tensorflow2-reinforcement-learning/blob/master/ipynb/rl/rainbow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Google ドライブをマウントするには、このセルを実行してください。
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/My Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import numpy as np

# %%
# %cd /content/drive/My Drive
from env import Env

try:
  import imp
  imp.reload(rainbow_noisy)
except:
  import rainbow_noisy

env = Env(spread=10, leverage=1000, step_size=96, available_assets_rate=0.8)
agent = rainbow_noisy.Agent(restore=True, n=3, lr=1e-3, env=env)
# Out:
# /content/drive/My Drive

# %%
agent.rewards.leverage = 500
agent.rewards.available_assets_rate = 0.9
agent.step_size = 96

# %%
# %cd /content

agent.run(train=True)
# Out:
# action probability: buy=0.5208333333333334, sell=0.3125, hold=0.16666666666666666
# epoch: 892005, total assets:364461074.45368403, growth_rate:3644.6107445368402, accuracy:0.7916666666666666
#
# action probability: buy=0.46875, sell=0.3854166666666667, hold=0.14583333333333334
# epoch: 892010, total assets:5261185.564443204, growth_rate:52.61185564443203, accuracy:0.7395833333333334
#
# action probability: buy=0.4270833333333333, sell=0.3541666666666667, hold=0.21875
# epoch: 892015, total assets:5447152.076831582, growth_rate:54.47152076831582, accuracy:0.75
#
# action probability: buy=0.40625, sell=0.4270833333333333, hold=0.16666666666666666
# epoch: 892020, total assets:3915704.316616129, growth_rate:39.157043166161294, accuracy:0.8020833333333334
#
# action probability: buy=0.5520833333333334, sell=0.3020833333333333, hold=0.14583333333333334
# epoch: 892025, total assets:2636721726.181216, growth_rate:26367.21726181216, accuracy:0.8333333333333334
#
# ...

# %%
from numba import cuda 
device = cuda.get_current_device()
device.reset()
